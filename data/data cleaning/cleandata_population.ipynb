# %%
import pandas as pd

# %%
df_raw = pd.read_excel('/home/chanwang1/CCC2024-BigDataAnalytics/data/raw/VIF2023_LGA_Pop_Age_Sex_Projections_to_2036.xlsx', sheet_name='ERP_by_Age_Persons')

# %%
df_raw
# Out:
#                                            Unnamed: 0          Unnamed: 1  \
# 0   Victoria in Future (VIF) population and househ...                 NaN
# 1                                      September 2023                 NaN
# 2   Contact: David Sykes (DTP) david.sykes@delwp.v...                 NaN
# 3                                                 NaN                 NaN
# 4   Estimated Resident Population (ERP) of all per...                 NaN
# ..                                                ...                 ...
# 85                                              27260         Wyndham (C)
# 86                                              27350           Yarra (C)
# 87                                              27450    Yarra Ranges (S)
# 88                                              27630    Yarriambiack (S)
# 89                                              29399  Unincorporated Vic
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
df = df_raw.iloc[8:]
df
# Out:
#    Unnamed: 0          Unnamed: 1     Unnamed: 2     Unnamed: 3  \
# 8   LGA  code                 LGA  Persons \n0-4  Persons \n5-9
# 9         NaN            Victoria         386670         407990
# 10      20110          Alpine (S)            540            680
# 11      20260         Ararat (RC)            580            620
# 12      20570        Ballarat (C)           6750           7350
# ..        ...                 ...            ...            ...
# 85      27260         Wyndham (C)          26850          27160
# 86      27350           Yarra (C)           3760           3150
# 87      27450    Yarra Ranges (S)           9620           9970
# 88      27630    Yarriambiack (S)            290            320
# 89      29399  Unincorporated Vic             40             40
#
#          Unnamed: 4       Unnamed: 5       Unnamed: 6       Unnamed: 7  \
# 8   Persons \n10-14  Persons \n15-19  Persons \n20-24  Persons \n25-29
# ...

# %%
df.columns=df.iloc[0]
df = df[1:]
df
# Out:
# 8  LGA  code                 LGA Persons \n0-4 Persons \n5-9 Persons \n10-14  \
# 9        NaN            Victoria        386670        407990          398510
# 10     20110          Alpine (S)           540           680             800
# 11     20260         Ararat (RC)           580           620             620
# 12     20570        Ballarat (C)          6750          7350            7500
# 13     20660         Banyule (C)          7250          7940            7710
# ..       ...                 ...           ...           ...             ...
# 85     27260         Wyndham (C)         26850         27160           21490
# 86     27350           Yarra (C)          3760          3150            2900
# 87     27450    Yarra Ranges (S)          9620          9970           10170
# 88     27630    Yarriambiack (S)           290           320             410
# 89     29399  Unincorporated Vic            40            40              60
#
# ...

# %%
df['LGA'] = df['LGA'].str.replace(r'\(.*?\)', '', regex=True)
# Out:
# /tmp/ipykernel_9943/1045999329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LGA'] = df['LGA'].str.replace(r'\(.*?\)', '', regex=True)

# %%
df
# Out:
# 8  LGA  code                 LGA Persons \n0-4 Persons \n5-9 Persons \n10-14  \
# 9        NaN            Victoria        386670        407990          398510
# 10     20110             Alpine            540           680             800
# 11     20260             Ararat            580           620             620
# 12     20570           Ballarat           6750          7350            7500
# 13     20660            Banyule           7250          7940            7710
# ..       ...                 ...           ...           ...             ...
# 85     27260            Wyndham          26850         27160           21490
# 86     27350              Yarra           3760          3150            2900
# 87     27450       Yarra Ranges           9620          9970           10170
# 88     27630       Yarriambiack            290           320             410
# 89     29399  Unincorporated Vic            40            40              60
#
# ...

# %%
df.columns
# Out:
# Index(['LGA  code', 'LGA', 'Persons \n0-4', 'Persons \n5-9', 'Persons \n10-14',
#        'Persons \n15-19', 'Persons \n20-24', 'Persons \n25-29',
#        'Persons \n30-34', 'Persons \n35-39', 'Persons \n40-44',
#        'Persons \n45-49', 'Persons \n50-54', 'Persons \n55-59',
#        'Persons \n60-64', 'Persons \n65-69', 'Persons \n70-74',
#        'Persons \n75-79', 'Persons \n80-84', 'Persons \n85+', 'Persons \n0-4',
#        'Persons \n5-9', 'Persons \n10-14', 'Persons \n15-19',
#        'Persons \n20-24', 'Persons \n25-29', 'Persons \n30-34',
#        'Persons \n35-39', 'Persons \n40-44', 'Persons \n45-49',
#        'Persons \n50-54', 'Persons \n55-59', 'Persons \n60-64',
#        'Persons \n65-69', 'Persons \n70-74', 'Persons \n75-79',
#        'Persons \n80-84', 'Persons \n85+', 'Persons \n0-4', 'Persons \n5-9',
#        'Persons \n10-14', 'Persons \n15-19', 'Persons \n20-24',
#        'Persons \n25-29', 'Persons \n30-34', 'Persons \n35-39',
# ...

# %%
df.rename(columns={df.columns[2]: '2021Persons0-4',df.columns[3]: '2021Persons5-9',df.columns[4]: '2021Persons10-14',
                   df.columns[5]: '2021Persons15-19',df.columns[6]: '2021Persons20-24',df.columns[7]: '2021Persons25-29',
                   df.columns[8]: '2021Persons30-34',df.columns[9]: '2021Persons35-39',df.columns[10]: '2021Persons40-44',
                   df.columns[11]: '2021Persons45-49',df.columns[12]: '2021Persons50-54',df.columns[13]: '2021Persons55-59',
                   df.columns[14]: '2021Persons60-64',df.columns[15]: '2021Persons65-69',df.columns[16]: '2021Persons70-74',
                   df.columns[17]: '2021Persons75-79',df.columns[18]: '2021Persons80-84',df.columns[19]: '2021Persons85+',}, inplace=True)
df
# Out:
# /tmp/ipykernel_9943/3833808827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={df.columns[2]: '2021Persons0-4',df.columns[3]: '2021Persons5-9',df.columns[4]: '2021Persons10-14',
# 8  LGA  code                 LGA 2021Persons0-4 2021Persons5-9  \
# 9        NaN            Victoria         386670         407990
# 10     20110             Alpine             540            680
# 11     20260             Ararat             580            620
# 12     20570           Ballarat            6750           7350
# 13     20660            Banyule            7250           7940
# ..       ...                 ...            ...            ...
# 85     27260            Wyndham           26850          27160
# 86     27350              Yarra            3760           3150
# ...

# %%
df2021=df.iloc[:,0:20]

df2021['2021Persons_total']=df2021.iloc[:,2:20].sum(axis=1)

df2021=df2021.iloc[1:80,:]

df2021

df2021.to_json('/home/chanwang1/CCC2024-BigDataAnalytics/data/cleaned/population2021.json')

# %%
df2026=df.iloc[:,[0,1]+list(range(20,38))]
df2026['2026Persons_total']=df2026.iloc[:,2:20].sum(axis=1)

df2026
# Out:
# /tmp/ipykernel_9943/172556147.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2026['2026Persons_total']=df2026.iloc[:,2:20].sum(axis=1)
# 8  LGA  code                 LGA 2021Persons0-4 2021Persons5-9  \
# 9        NaN            Victoria         410490         406020
# 10     20110             Alpine             580            610
# 11     20260             Ararat             540            510
# 12     20570           Ballarat            7070           7140
# 13     20660            Banyule            7030           7290
# ..       ...                 ...            ...            ...
# 85     27260            Wyndham           33650          29360
# 86     27350              Yarra            3960           2650
# ...

# %%
df2026.rename(columns={df.columns[2]: '2026Persons0-4',df.columns[3]: '2026Persons5-9',df.columns[4]: '2026Persons10-14',
                   df.columns[5]: '2026Persons15-19',df.columns[6]: '2026Persons20-24',df.columns[7]: '2026Persons25-29',
                   df.columns[8]: '2026Persons30-34',df.columns[9]: '2026Persons35-39',df.columns[10]: '2026Persons40-44',
                   df.columns[11]: '2026Persons45-49',df.columns[12]: '2026Persons50-54',df.columns[13]: '2026Persons55-59',
                   df.columns[14]: '2026Persons60-64',df.columns[15]: '2026Persons65-69',df.columns[16]: '2026Persons70-74',
                   df.columns[17]: '2026Persons75-79',df.columns[18]: '2026Persons80-84',df.columns[19]: '2026Persons85+',}, inplace=True)
# Out:
# /tmp/ipykernel_9943/4154427847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2026.rename(columns={df.columns[2]: '2026Persons0-4',df.columns[3]: '2026Persons5-9',df.columns[4]: '2026Persons10-14',

# %%
df2026=df2026.iloc[1:80,:]

df2026
# Out:
# 8  LGA  code            LGA 2026Persons0-4 2026Persons5-9 2026Persons10-14  \
# 10     20110        Alpine             580            610              730
# 11     20260        Ararat             540            510              600
# 12     20570      Ballarat            7070           7140             7800
# 13     20660       Banyule            7030           7290             8190
# 14     20740    Bass Coast            1920           2030             2340
# ..       ...            ...            ...            ...              ...
# 84     27170       Wodonga            2920           2740             3070
# 85     27260       Wyndham           33650          29360            28510
# 86     27350         Yarra            3960           2650             3070
# 87     27450  Yarra Ranges            8860          10210            10370
# 88     27630  Yarriambiack             290            310              320
#
# ...

# %%
df2026.to_json('/home/chanwang1/CCC2024-BigDataAnalytics/data/cleaned/population2026.json')
