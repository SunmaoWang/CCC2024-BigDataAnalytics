# %%
import json
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
# Load the data from JSON file
with open('../cleaned/epa_data.json', 'r') as file:
    data = json.load(file)

lga_geojson_path = '../cleaned/LGA_useful_geo/lga_for_join.json'
lga_gdf = gpd.read_file(lga_geojson_path)

# %%
# Extract relevant information
site_data = []
for record in data['records']:
    site_name = record['siteName']
    coordinates = record['geometry']['coordinates']
    latitude, longitude = coordinates[0], coordinates[1]
    
    site_data.append({
        'siteName': site_name,
        'latitude': latitude,
        'longitude': longitude
    })

# Create DataFrame
df_sites = pd.DataFrame(site_data).drop_duplicates(subset='siteName')

# Check the DataFrame
df_sites
# Out:
#            siteName   latitude   longitude
# 0          Box Hill -37.828728  145.132400
# 1        Alphington -37.778408  145.030600
# 2         Churchill -38.304314  146.414932
# 3   Traralgon South -38.295850  146.539200
# 4         Traralgon -38.194282  146.531464
# ..              ...        ...         ...
# 88      Mooroolbark -37.775120  145.328400
# 89        Footscray -37.802660  144.877800
# 90         Brooklyn -37.822098  144.847100
# 91          Bendigo -36.778410  144.300064
# 92       Porepunkah -36.704190  146.916900
#
# [89 rows x 3 columns]

# %%
# Convert DataFrame to GeoDataFrame
df_sites['geometry'] = df_sites.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)
sites_gdf = gpd.GeoDataFrame(df_sites, geometry='geometry')

# Set the same CRS as the LGA data to ensure accurate spatial operations
sites_gdf.crs = lga_gdf.crs

# %%
# Perform spatial join
joined_gdf = gpd.sjoin(sites_gdf, lga_gdf, how="inner", op='intersects')

# Select relevant columns
final_gdf = joined_gdf[['ABSLGACODE', 'LGA_NAME', 'siteName', 'latitude', 'longitude']]

# Check the resulting GeoDataFrame
final_gdf
# Out:
# /Users/sunmaowang/Library/Python/3.12/lib/python/site-packages/IPython/core/interactiveshell.py:3517: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#    ABSLGACODE         LGA_NAME         siteName   latitude   longitude
# 0       26980       whitehorse         Box Hill -37.828728  145.132400
# 1       21890          darebin       Alphington -37.778408  145.030600
# 2       23810          latrobe        Churchill -38.304314  146.414932
# 3       23810          latrobe  Traralgon South -38.295850  146.539200
# 4       23810          latrobe        Traralgon -38.194282  146.531464
# ..        ...              ...              ...        ...         ...
# 88      27450     yarra ranges      Mooroolbark -37.775120  145.328400
# 89      24330      maribyrnong        Footscray -37.802660  144.877800
# 90      23110      hobsons bay         Brooklyn -37.822098  144.847100
# 91      22620  greater bendigo          Bendigo -36.778410  144.300064
# 92      20110           alpine       Porepunkah -36.704190  146.916900
#
# [89 rows x 5 columns]

# %%
final_gdf.set_index('siteName', inplace=True)

data_dict = final_gdf.to_dict(orient='index')

print(json.dumps(data_dict, indent=4))
# Out:
# {
#     "Box Hill": {
#         "ABSLGACODE": "26980",
#         "LGA_NAME": "whitehorse",
#         "latitude": -37.8287277,
#         "longitude": 145.1324
#     },
#     "Alphington": {
#         "ABSLGACODE": "21890",
#         "LGA_NAME": "darebin",
#         "latitude": -37.7784081,
#         "longitude": 145.0306
#     },
#     "Churchill": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.3043137,
#         "longitude": 146.414932
#     },
#     "Traralgon South": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.29585,
#         "longitude": 146.5392
#     },
#     "Traralgon": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.1942825,
#         "longitude": 146.531464
#     },
#     "Tyers North": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.12967,
#         "longitude": 146.4828
#     },
#     "Dandenong": {
#         "ABSLGACODE": "22670",
#         "LGA_NAME": "greater dandenong",
#         "latitude": -37.98576,
#         "longitude": 145.1987
#     },
#     "Moe": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.1864662,
#         "longitude": 146.258331
#     },
#     "Boolarra South": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.44398,
#         "longitude": 146.2742
#     },
#     "Traralgon East": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.19631,
#         "longitude": 146.5621
#     },
#     "Boolarra": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.36981,
#         "longitude": 146.2751
#     },
#     "Yinnar": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.32779,
#         "longitude": 146.3371
#     },
#     "Morwell East": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.229393,
#         "longitude": 146.424454
#     },
#     "Geelong South": {
#         "ABSLGACODE": "22750",
#         "LGA_NAME": "greater geelong",
#         "latitude": -38.17356,
#         "longitude": 144.3703
#     },
#     "Willow Grove": {
#         "ABSLGACODE": "20830",
#         "LGA_NAME": "baw baw",
#         "latitude": -38.07072,
#         "longitude": 146.1779
#     },
#     "Yallourn North": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.16144,
#         "longitude": 146.3629
#     },
#     "Point Cook": {
#         "ABSLGACODE": "27260",
#         "LGA_NAME": "wyndham",
#         "latitude": -37.9263153,
#         "longitude": 144.7567
#     },
#     "Flynns Creek": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.24396,
#         "longitude": 146.6362
#     },
#     "Melbourne CBD": {
#         "ABSLGACODE": "24600",
#         "LGA_NAME": "melbourne",
#         "latitude": -37.8073959,
#         "longitude": 144.97
#     },
#     "Tyers": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.1300278,
#         "longitude": 146.482513
#     },
#     "Callignee": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.36169,
#         "longitude": 146.588211
#     },
#     "Hernes Oak": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.1853447,
#         "longitude": 146.323441
#     },
#     "Wangaratta": {
#         "ABSLGACODE": "26700",
#         "LGA_NAME": "wangaratta",
#         "latitude": -36.36926,
#         "longitude": 146.3133
#     },
#     "Morwell South": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.2392921,
#         "longitude": 146.3873
#     },
#     "Brighton": {
#         "ABSLGACODE": "20910",
#         "LGA_NAME": "bayside",
#         "latitude": -37.9135475,
#         "longitude": 144.998
#     },
#     "Echuca": {
#         "ABSLGACODE": "21370",
#         "LGA_NAME": "campaspe",
#         "latitude": -36.12591,
#         "longitude": 144.754288
#     },
#     "Healesville": {
#         "ABSLGACODE": "27450",
#         "LGA_NAME": "yarra ranges",
#         "latitude": -37.6468239,
#         "longitude": 145.5275
#     },
#     "Warrnambool": {
#         "ABSLGACODE": "26730",
#         "LGA_NAME": "warrnambool",
#         "latitude": -38.3860931,
#         "longitude": 142.510986
#     },
#     "Mildura": {
#         "ABSLGACODE": "24780",
#         "LGA_NAME": "mildura",
#         "latitude": -34.1635132,
#         "longitude": 142.139374
#     },
#     "Horsham": {
#         "ABSLGACODE": "23190",
#         "LGA_NAME": "horsham",
#         "latitude": -36.72263,
#         "longitude": 142.175415
#     },
#     "Altona North": {
#         "ABSLGACODE": "23110",
#         "LGA_NAME": "hobsons bay",
#         "latitude": -37.8441238,
#         "longitude": 144.861618
#     },
#     "Ballarat": {
#         "ABSLGACODE": "20570",
#         "LGA_NAME": "ballarat",
#         "latitude": -37.5293274,
#         "longitude": 143.842438
#     },
#     "Bairnsdale": {
#         "ABSLGACODE": "22110",
#         "LGA_NAME": "east gippsland",
#         "latitude": -37.829895,
#         "longitude": 147.620209
#     },
#     "Castlemaine": {
#         "ABSLGACODE": "25430",
#         "LGA_NAME": "mount alexander",
#         "latitude": -37.0730247,
#         "longitude": 144.233292
#     },
#     "Beechworth": {
#         "ABSLGACODE": "23350",
#         "LGA_NAME": "indigo",
#         "latitude": -36.37299,
#         "longitude": 146.679077
#     },
#     "Benalla": {
#         "ABSLGACODE": "21010",
#         "LGA_NAME": "benalla",
#         "latitude": -36.54932,
#         "longitude": 145.997223
#     },
#     "Ararat": {
#         "ABSLGACODE": "20260",
#         "LGA_NAME": "ararat",
#         "latitude": -37.2828064,
#         "longitude": 142.935608
#     },
#     "Cobden": {
#         "ABSLGACODE": "21830",
#         "LGA_NAME": "corangamite",
#         "latitude": -38.32716,
#         "longitude": 143.076
#     },
#     "Camperdown": {
#         "ABSLGACODE": "21830",
#         "LGA_NAME": "corangamite",
#         "latitude": -38.2248344,
#         "longitude": 143.140152
#     },
#     "Colac": {
#         "ABSLGACODE": "21750",
#         "LGA_NAME": "colac-otway",
#         "latitude": -38.3456841,
#         "longitude": 143.594269
#     },
#     "Maffra": {
#         "ABSLGACODE": "26810",
#         "LGA_NAME": "wellington",
#         "latitude": -37.9596977,
#         "longitude": 146.991745
#     },
#     "Gisborne": {
#         "ABSLGACODE": "24130",
#         "LGA_NAME": "macedon ranges",
#         "latitude": -37.4853172,
#         "longitude": 144.5862
#     },
#     "Macedon": {
#         "ABSLGACODE": "24130",
#         "LGA_NAME": "macedon ranges",
#         "latitude": -37.4230652,
#         "longitude": 144.562225
#     },
#     "Lancefield": {
#         "ABSLGACODE": "24130",
#         "LGA_NAME": "macedon ranges",
#         "latitude": -37.2782669,
#         "longitude": 144.73526
#     },
#     "Kyneton": {
#         "ABSLGACODE": "24130",
#         "LGA_NAME": "macedon ranges",
#         "latitude": -37.24706,
#         "longitude": 144.451111
#     },
#     "Heathcote": {
#         "ABSLGACODE": "22620",
#         "LGA_NAME": "greater bendigo",
#         "latitude": -36.92107,
#         "longitude": 144.709946
#     },
#     "Kinglake": {
#         "ABSLGACODE": "25620",
#         "LGA_NAME": "murrindindi",
#         "latitude": -37.5337448,
#         "longitude": 145.340515
#     },
#     "Daylesford": {
#         "ABSLGACODE": "22910",
#         "LGA_NAME": "hepburn",
#         "latitude": -37.3410339,
#         "longitude": 144.130463
#     },
#     "Heywood": {
#         "ABSLGACODE": "22410",
#         "LGA_NAME": "glenelg",
#         "latitude": -38.1323051,
#         "longitude": 141.631821
#     },
#     "Hamilton": {
#         "ABSLGACODE": "26260",
#         "LGA_NAME": "southern grampians",
#         "latitude": -37.73387,
#         "longitude": 142.020813
#     },
#     "Kerang": {
#         "ABSLGACODE": "22250",
#         "LGA_NAME": "gannawarra",
#         "latitude": -35.7475281,
#         "longitude": 143.924866
#     },
#     "Lorne": {
#         "ABSLGACODE": "26490",
#         "LGA_NAME": "surf coast",
#         "latitude": -38.5403671,
#         "longitude": 143.9738
#     },
#     "Mallacoota": {
#         "ABSLGACODE": "22110",
#         "LGA_NAME": "east gippsland",
#         "latitude": -37.56016,
#         "longitude": 149.751114
#     },
#     "Shepparton": {
#         "ABSLGACODE": "22830",
#         "LGA_NAME": "greater shepparton",
#         "latitude": -36.3808365,
#         "longitude": 145.406616
#     },
#     "Orbost": {
#         "ABSLGACODE": "22110",
#         "LGA_NAME": "east gippsland",
#         "latitude": -37.7059746,
#         "longitude": 148.456284
#     },
#     "Sale": {
#         "ABSLGACODE": "26810",
#         "LGA_NAME": "wellington",
#         "latitude": -38.102684,
#         "longitude": 147.057541
#     },
#     "Myrtleford": {
#         "ABSLGACODE": "20110",
#         "LGA_NAME": "alpine",
#         "latitude": -36.5539742,
#         "longitude": 146.72081
#     },
#     "Mansfield": {
#         "ABSLGACODE": "24250",
#         "LGA_NAME": "mansfield",
#         "latitude": -37.0508,
#         "longitude": 146.077087
#     },
#     "Portland": {
#         "ABSLGACODE": "22410",
#         "LGA_NAME": "glenelg",
#         "latitude": -38.3525276,
#         "longitude": 141.6071
#     },
#     "Ouyen": {
#         "ABSLGACODE": "24780",
#         "LGA_NAME": "mildura",
#         "latitude": -35.0655365,
#         "longitude": 142.318649
#     },
#     "Torquay": {
#         "ABSLGACODE": "26490",
#         "LGA_NAME": "surf coast",
#         "latitude": -38.3079338,
#         "longitude": 144.310516
#     },
#     "Wonthaggi": {
#         "ABSLGACODE": "20740",
#         "LGA_NAME": "bass coast",
#         "latitude": -38.5871048,
#         "longitude": 145.578491
#     },
#     "Warragul": {
#         "ABSLGACODE": "20830",
#         "LGA_NAME": "baw baw",
#         "latitude": -38.1666527,
#         "longitude": 145.941544
#     },
#     "Yarrawonga": {
#         "ABSLGACODE": "24900",
#         "LGA_NAME": "moira",
#         "latitude": -36.01634,
#         "longitude": 146.013016
#     },
#     "Wodonga": {
#         "ABSLGACODE": "27170",
#         "LGA_NAME": "wodonga",
#         "latitude": -36.1377754,
#         "longitude": 146.8983
#     },
#     "Broadford": {
#         "ABSLGACODE": "24850",
#         "LGA_NAME": "mitchell",
#         "latitude": -37.2078857,
#         "longitude": 145.04805
#     },
#     "Yarra Glen": {
#         "ABSLGACODE": "27450",
#         "LGA_NAME": "yarra ranges",
#         "latitude": -37.65686,
#         "longitude": 145.373459
#     },
#     "Sunbury": {
#         "ABSLGACODE": "23270",
#         "LGA_NAME": "hume",
#         "latitude": -37.58954,
#         "longitude": 144.719727
#     },
#     "Lakes Entrance": {
#         "ABSLGACODE": "22110",
#         "LGA_NAME": "east gippsland",
#         "latitude": -37.8716469,
#         "longitude": 148.006744
#     },
#     "Leongatha": {
#         "ABSLGACODE": "26170",
#         "LGA_NAME": "south gippsland",
#         "latitude": -38.4689522,
#         "longitude": 145.956421
#     },
#     "Bacchus Marsh": {
#         "ABSLGACODE": "25150",
#         "LGA_NAME": "moorabool",
#         "latitude": -37.674633,
#         "longitude": 144.4354
#     },
#     "Warburton": {
#         "ABSLGACODE": "27450",
#         "LGA_NAME": "yarra ranges",
#         "latitude": -37.75449,
#         "longitude": 145.688278
#     },
#     "Drysdale": {
#         "ABSLGACODE": "22750",
#         "LGA_NAME": "greater geelong",
#         "latitude": -38.1913528,
#         "longitude": 144.550659
#     },
#     "Rutherglen": {
#         "ABSLGACODE": "23350",
#         "LGA_NAME": "indigo",
#         "latitude": -36.0538254,
#         "longitude": 146.463989
#     },
#     "Bright": {
#         "ABSLGACODE": "20110",
#         "LGA_NAME": "alpine",
#         "latitude": -36.73228,
#         "longitude": 146.9702
#     },
#     "Macleod": {
#         "ABSLGACODE": "21890",
#         "LGA_NAME": "darebin",
#         "latitude": -37.722477,
#         "longitude": 145.0576
#     },
#     "Swan Hill": {
#         "ABSLGACODE": "26610",
#         "LGA_NAME": "swan hill",
#         "latitude": -35.34331,
#         "longitude": 143.5341
#     },
#     "Spotswood": {
#         "ABSLGACODE": "23110",
#         "LGA_NAME": "hobsons bay",
#         "latitude": -37.82743,
#         "longitude": 144.8801
#     },
#     "Wallan": {
#         "ABSLGACODE": "24850",
#         "LGA_NAME": "mitchell",
#         "latitude": -37.41652,
#         "longitude": 144.981232
#     },
#     "Rosedale": {
#         "ABSLGACODE": "26810",
#         "LGA_NAME": "wellington",
#         "latitude": -38.15588,
#         "longitude": 146.7842
#     },
#     "Kingsville": {
#         "ABSLGACODE": "24330",
#         "LGA_NAME": "maribyrnong",
#         "latitude": -37.81191,
#         "longitude": 144.8741
#     },
#     "Flynn": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.17107,
#         "longitude": 146.6933
#     },
#     "Glengarry": {
#         "ABSLGACODE": "23810",
#         "LGA_NAME": "latrobe",
#         "latitude": -38.12751,
#         "longitude": 146.5691
#     },
#     "Melton": {
#         "ABSLGACODE": "24650",
#         "LGA_NAME": "melton",
#         "latitude": -37.7064552,
#         "longitude": 144.5669
#     },
#     "Mooroolbark": {
#         "ABSLGACODE": "27450",
#         "LGA_NAME": "yarra ranges",
#         "latitude": -37.77512,
#         "longitude": 145.3284
#     },
#     "Footscray": {
#         "ABSLGACODE": "24330",
#         "LGA_NAME": "maribyrnong",
#         "latitude": -37.80266,
#         "longitude": 144.8778
#     },
#     "Brooklyn": {
#         "ABSLGACODE": "23110",
#         "LGA_NAME": "hobsons bay",
#         "latitude": -37.8220978,
#         "longitude": 144.8471
#     },
#     "Bendigo": {
#         "ABSLGACODE": "22620",
#         "LGA_NAME": "greater bendigo",
#         "latitude": -36.77841,
#         "longitude": 144.300064
#     },
#     "Porepunkah": {
#         "ABSLGACODE": "20110",
#         "LGA_NAME": "alpine",
#         "latitude": -36.70419,
#         "longitude": 146.9169
#     }
# }

# %%
with open('matched_sites_with_lgas.json', 'w') as json_file:
    json.dump(data_dict, json_file)
