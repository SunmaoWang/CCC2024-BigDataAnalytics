# %%
import pandas as pd

# %%
df_raw = pd.read_csv('data/raw/income.csv')

# %%
df_raw
# Out:
#      median_aud   median_age_of_earners_years   earners_persons   lga_code  \
# 0         38607                            49              7546      20110
# 1         43190                            47              6215      20260
# 2         47859                            43             57540      20570
# 3         54519                            43             76202      20660
# 4         37559                            49             18630      20740
# ..          ...                           ...               ...        ...
# 74        63503                            35             62165      27350
# 75        49136                            44             91872      27450
# 76        45898                            51              3624      27630
# 77        55256                            42             92499      22310
# 78        44647                            48             10907      22410
#
#      gini_coefficient_coef      lga_name   mean_aud       sum_aud
# ...

# %%
df_raw.to_json('data/income2017.json')
